# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../../Data/cleaned_data/green_roofs.csv')

df
# Out:
#      green_roof_area  building_area  ratio_green_area  construction_year  \
# 0                971          14057              0.07               1900
# 1                696           4463              0.16               1900
# 2                293          13217              0.02               1900
# 3                759           4311              0.18               1900
# 4               7204          35891              0.20               1990
# ..               ...            ...               ...                ...
# 728             1525           6414              0.24               1800
# 729              343           2941              0.12               1990
# 730              309           4350              0.07               1990
# 731             8139          20051              0.41               1960
# 732              357           2164              0.17               1900
#
#      roof_height  ground_elev  digitized borough    xcoord    ycoord  \
# 0             59           90          1      BK -73.93491  40.67389
# 1             13           21          0      MN -73.99982  40.73481
# 2             93            7          0      MN -74.00906  40.72480
# 3             99           21          0      MN -74.00836  40.71595
# 4            206           10          1      BX -73.91227  40.81906
# ..           ...          ...        ...     ...       ...       ...
# 728          104            6          0      MN -74.00968  40.72554
# 729          118           42          1      MN -73.99311  40.72600
# 730          175           18          1      MN -74.01044  40.71474
# 731           23           12          0      MN -73.93708  40.79703
# 732           84           10          0      MN -74.00959  40.72423
#
#        area_type
# 0         public
# 1     commercial
# 2     commercial
# 3     commercial
# 4     commercial
# ..           ...
# 728  residential
# 729       public
# 730   industrial
# 731   commercial
# 732   industrial
#
# [733 rows x 11 columns]

# %%
df.info() # for some reason pandas didn't detect before the Null value on te column 'area_type'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 733 entries, 0 to 732
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   green_roof_area    733 non-null    int64
#  1   building_area      733 non-null    int64
#  2   ratio_green_area   733 non-null    float64
#  3   construction_year  733 non-null    int64
#  4   roof_height        733 non-null    int64
#  5   ground_elev        733 non-null    int64
#  6   digitized          733 non-null    int64
#  7   borough            733 non-null    object
#  8   xcoord             733 non-null    float64
#  9   ycoord             733 non-null    float64
#  10  area_type          732 non-null    object
# dtypes: float64(3), int64(6), object(2)
# memory usage: 63.1+ KB

# %%
# we'll replace it by the mode

mode = df['area_type'].mode()[0]
mode

df['area_type'] = df['area_type'].fillna(mode)

df['area_type'].isna().sum()
# Out:
# 0

# %%
#Columns to check ouliers: green_roof_area, building_area, ratio_green_area, roof_height, ground_elev

#green_roof_area

fig,ax = plt.subplots(figsize = (5,5))
sns.boxplot(data = df, y = 'green_roof_area')
plt.show()

# %%
Q1 = df['green_roof_area'].quantile(0.25)
Q3 = df['green_roof_area'].quantile(0.75)

IQR = Q3 - Q1

lower_wisker1 = Q1 - 1.5*IQR
upper_wisker1 = Q3 + 1.5*IQR

print(lower_wisker1) # this wisker don't have any meaning because we only have positive values
print(upper_wisker1)
# Out:
# -3595.5
# 7176.5

# %%
#checking the rows with ouliers

df[df['green_roof_area']>upper_wisker1].sort_values('green_roof_area', ascending= False )
# Out:
#      green_roof_area  building_area  ratio_green_area  construction_year  \
# 165           277317         692314              0.40               1960
# 33            128158         200331              0.64               1990
# 344            66025         224776              0.29               1990
# 641            55140         126149              0.44               1990
# 10             54774         152909              0.36               1930
# ..               ...            ...               ...                ...
# 509             7864          30244              0.26               1990
# 291             7636          47484              0.16               1990
# 222             7457          18317              0.41               1930
# 448             7239          12510              0.58               1930
# 4               7204          35891              0.20               1990
#
#      roof_height  ground_elev  digitized borough    xcoord    ycoord  \
# 165          175           15          1      MN -74.00239  40.75795
# 33           137           43          1      BK -73.97516  40.68260
# 344           50            7          1      BK -74.01159  40.67161
# 641           74            9          1      MN -73.93698  40.82205
# 10           179           90          0      MN -73.98513  40.77092
# ..           ...          ...        ...     ...       ...       ...
# 509          208           37          0      MN -73.99350  40.73544
# 291          122           84          0      SI -74.07732  40.64069
# 222          342           35          0      MN -73.97444  40.75028
# 448           25           64          1      BX -73.89054  40.81822
# 4            206           10          1      BX -73.91227  40.81906
#
#        area_type
# 165  residential
# 33    commercial
# 344  residential
# 641   commercial
# 10    commercial
# ..           ...
# 509   commercial
# 291   commercial
# 222   commercial
# 448  residential
# 4     commercial
#
# [73 rows x 11 columns]

# %%
#CONCLUSION: two big outliers in rows 165 and 33

#DECISION: we'll drop the row 33. regarding row 165, see the next decision step

df.drop(index = 33, inplace = True)

# %%
#building_area

fig,ax = plt.subplots(figsize = (5,5))
sns.boxplot(data = df, y = 'building_area')
plt.show()

# %%
Q1 = df['building_area'].quantile(0.25)
Q3 = df['building_area'].quantile(0.75)

IQR = Q3 - Q1

lower_wisker2 = Q1 - 1.5*IQR
upper_wisker2 = Q3 + 1.5*IQR

print(lower_wisker2) # this wisker don't have any meaning because we only have positive values
print(upper_wisker2)
# Out:
# -30780.625
# 62794.375

# %%
#checking the rows with ouliers

df[df['building_area']>upper_wisker2].sort_values('building_area', ascending= False )
# Out:
#      green_roof_area  building_area  ratio_green_area  construction_year  \
# 165           277317         692314              0.40               1960
# 566             9075         280739              0.03               1990
# 344            66025         224776              0.29               1990
# 694              722         178941              0.00               1960
# 55              4160         177959              0.02               1960
# 247            52131         174248              0.30               1930
# 141             8324         163605              0.05               1930
# 727              466         163243              0.00               1930
# 273             8915         162276              0.05               1990
# 282             9518         157733              0.06               1960
# 526             3321         155406              0.02               1960
# 10             54774         152909              0.36               1930
# 115             4848         145737              0.03               1990
# 497             8971         140402              0.06               1930
# 508             3637         139709              0.03               1960
# 705            15220         133265              0.11               1960
# 214              610         133204              0.00               1930
# 303             2441         127092              0.02               1900
# 641            55140         126149              0.44               1990
# 551             5852         115176              0.05               1990
# 407            10032         112685              0.09               1960
# 142            23421         108557              0.22               1990
# 367            12907         104089              0.12               1990
# 441            11895         100651              0.12               1930
# 499            11006         100293              0.11               1960
# 723             1072          99099              0.01               1960
# 573            14475          98911              0.15               1930
# 450            28669          94646              0.30               1990
# 695            10755          94358              0.11               1990
# 179             5942          94054              0.06               1990
# 654             4266          92654              0.05               1990
# 666            15112          90706              0.17               1960
# 160             6555          87895              0.07               1930
# 400            13282          87601              0.15               1960
# 11              2010          86153              0.02               1960
# 171             7992          85500              0.09               1930
# 467             5126          85062              0.06               1990
# 409            49895          83074              0.60               1990
# 127             5171          81471              0.06               1930
# 474             8020          79527              0.10               1960
# 382             6672          78619              0.08               1990
# 201             3102          76799              0.04               1900
# 289            12892          76300              0.17               1960
# 558             4135          72811              0.06               1960
# 278             5484          71917              0.08               1960
# 265             2642          71875              0.04               1960
# 665             5082          71774              0.07               1960
# 582             3101          71264              0.04               1990
# 618            10351          70910              0.15               1960
# 148             9737          69806              0.14               1990
# 584              144          66989              0.00               1900
# 89              3798          66508              0.06               1990
# 147             1039          65516              0.02               1930
# 552            41338          65005              0.64               1930
# 266            32252          64956              0.50               1990
# 68             25420          63467              0.40               1990
# 53              6416          62987              0.10               1990
# 118              545          62952              0.01               1930
#
#      roof_height  ground_elev  digitized borough    xcoord    ycoord  \
# 165          175           15          1      MN -74.00239  40.75795
# 566           79           13          1      QN -73.84498  40.75786
# 344           50            7          1      BK -74.01159  40.67161
# 694           76           48          0      QN -73.79531  40.70178
# 55            71           12          0      MN -73.94739  40.76373
# 247          201           25          1      MN -74.00012  40.75131
# 141          103           56          0      QN -73.82459  40.74697
# 727          259           19          0      MN -74.00317  40.74108
# 273           79           13          0      QN -73.83997  40.77192
# 282          296           49          0      BK -74.02450  40.63926
# 526          646           12          0      MN -74.01587  40.71269
# 10           179           90          0      MN -73.98513  40.77092
# 115          714           84          0      MN -73.98330  40.76811
# 497           60            2          1      SI -74.07381  40.64427
# 508          258           56          0      BK -74.02255  40.63814
# 705           48           20          1      BX -73.85659  40.82161
# 214          320           43          0      MN -73.98971  40.75079
# 303          191            9          0      BK -74.00009  40.69312
# 641           74            9          1      MN -73.93698  40.82205
# 551           82           27          0      BX -73.92364  40.82216
# 407           35           12          1      BX -73.88361  40.82400
# 142          194            9          0      QN -73.83522  40.75695
# 367          185           22          0      QN -73.83515  40.75746
# 441           46           18          1      QN -73.94453  40.75095
# 499           28            7          0      MN -73.97324  40.73741
# 723           64           70          0      MN -73.98640  40.77521
# 573          834           64          1      MN -73.97996  40.75927
# 450          216           51          0      MN -73.98944  40.77076
# 695          145           41          0      BK -73.98302  40.69134
# 179           50           14          0      MN -73.99309  40.77150
# 654           38           30          1      MN -73.99233  40.76789
# 666          483           66          0      MN -73.97989  40.76240
# 160          103           17          0      QN -73.85142  40.74705
# 400          117           14          0      QN -73.82138  40.58584
# 11           568           65          0      MN -73.97867  40.76009
# 171         1238           50          1      MN -73.98571  40.74847
# 467          887           60          1      MN -73.98505  40.75573
# 409          129           12          1      MN -74.01023  40.72684
# 127          442           36          0      MN -73.98658  40.74159
# 474           35           12          0      BK -73.93676  40.57773
# 382          393            6          0      QN -73.95598  40.74780
# 201          178           10          0      MN -74.00847  40.73639
# 289          273           43          1      MN -73.98913  40.73458
# 558          295           13          0      MN -73.93756  40.79150
# 278           92           74          1      MN -73.98408  40.77341
# 265          179          141          0      MN -73.95991  40.80734
# 665          162           14          0      MN -74.01522  40.71501
# 582          755           35          0      MN -73.98978  40.75595
# 618           35           14          1      QN -73.95274  40.75167
# 148          740            9          1      MN -74.01452  40.71437
# 584          389           48          0      MN -73.97564  40.75268
# 89           328           10          0      MN -74.00349  40.75177
# 147           71           10          0      MN -73.97333  40.73641
# 552          142           12          1      BK -73.97255  40.69840
# 266          299           85          0      MN -73.96655  40.79472
# 68            35           14          1      MN -73.92309  40.79931
# 53            80           99          0      MN -73.97376  40.78174
# 118          245           11          0      MN -74.00637  40.72364
#
#        area_type
# 165  residential
# 566  residential
# 344  residential
# 694  residential
# 55    commercial
# 247  residential
# 141  residential
# 727  residential
# 273   commercial
# 282  residential
# 526  residential
# 10    commercial
# 115  residential
# 497  residential
# 508  residential
# 705   commercial
# 214   commercial
# 303  residential
# 641   commercial
# 551  residential
# 407  residential
# 142  residential
# 367  residential
# 441  residential
# 499   commercial
# 723  residential
# 573  residential
# 450   industrial
# 695  residential
# 179  residential
# 654  residential
# 666   commercial
# 160   commercial
# 400   commercial
# 11    commercial
# 171   industrial
# 467   commercial
# 409   industrial
# 127  residential
# 474   commercial
# 382  residential
# 201   industrial
# 289   commercial
# 558  residential
# 278   commercial
# 265   industrial
# 665   commercial
# 582  residential
# 618   commercial
# 148  residential
# 584  residential
# 89   residential
# 147   commercial
# 552   commercial
# 266  residential
# 68    industrial
# 53   residential
# 118  residential

# %%
#CONCLUSION: one big outliers in row 165 (the same outlier in green_roof_area)

#DECISION: drop row 165!

df.drop(index = 165, inplace = True)

# %%
#ratio_green_area

fig,ax = plt.subplots(figsize = (5,5))
sns.boxplot(data = df, y = 'ratio_green_area')
plt.show()

# %%
Q1 = df['ratio_green_area'].quantile(0.25)
Q3 = df['ratio_green_area'].quantile(0.75)

IQR = Q3 - Q1

lower_wisker3 = Q1 - 1.5*IQR
upper_wisker3 = Q3 + 1.5*IQR

print(lower_wisker3) # this wisker don't have any meaning because we only have positive values
print(upper_wisker3)
# Out:
# -0.195
# 0.485

# %%
#checking the rows with ouliers

df[df['ratio_green_area']>upper_wisker3].sort_values('ratio_green_area', ascending= False )
# Out:
#      green_roof_area  building_area  ratio_green_area  construction_year  \
# 261             1632            129             12.56               1990
# 256             3630           3721              0.98               1930
# 614             3831           4231              0.91               1960
# 415             3025           3646              0.83               1930
# 445              574            721              0.80               1900
# 102             9743          12154              0.80               1930
# 660              719            925              0.78               1990
# 458             1610           2086              0.77               1900
# 97               779           1031              0.76               1900
# 143             1396           1882              0.74               1990
# 232             5365           7298              0.74               1990
# 99              1232           1670              0.74               1990
# 124             1601           2214              0.72               1990
# 175              573            808              0.71               1850
# 527             4440           6399              0.69               1930
# 113             1600           2343              0.68               1990
# 379             2785           4116              0.68               1930
# 217            27247          41670              0.65               1900
# 177             6325           9955              0.64               1960
# 552            41338          65005              0.64               1930
# 676             4492           7158              0.63               1990
# 108             6043           9654              0.63               1990
# 378             6713          10654              0.63               1960
# 276              360            585              0.62               1990
# 168              405            678              0.60               1850
# 490             4853           8049              0.60               1900
# 409            49895          83074              0.60               1990
# 482            12761          21272              0.60               1900
# 111             1415           2389              0.59               1990
# 581             2784           4755              0.59               1900
# 325              651           1096              0.59               1900
# 555              586           1012              0.58               1900
# 480             1091           1886              0.58               1900
# 448             7239          12510              0.58               1930
# 719             1889           3267              0.58               1930
# 684             6935          12477              0.56               1960
# 76               788           1413              0.56               1900
# 514             6402          11684              0.55               1930
# 18               639           1166              0.55               1900
# 24              6256          11437              0.55               1850
# 678              470            862              0.55               1900
# 57              1535           2776              0.55               1900
# 525              475            885              0.54               1850
# 272              280            522              0.54               1900
# 544              639           1182              0.54               1900
# 653            22102          41835              0.53               1960
# 56              1794           3370              0.53               1960
# 658             1084           2049              0.53               1900
# 164             1313           2538              0.52               1900
# 440              959           1862              0.51               1930
# 608            14489          28215              0.51               1960
# 610            14971          29327              0.51               1960
# 726             8592          17045              0.50               1930
# 631             2834           5664              0.50               1900
# 478              847           1702              0.50               1930
# 266            32252          64956              0.50               1990
# 353             1125           2276              0.49               1930
# 101             2748           5647              0.49               1900
# 45              6643          13488              0.49               1930
# 381            16067          32603              0.49               1960
#
#      roof_height  ground_elev  digitized borough    xcoord    ycoord  \
# 261            8           41          1      QN -73.93737  40.75018
# 256           15           38          0      BK -74.03206  40.60893
# 614           13           26          0      MN -73.98404  40.71603
# 415           20           33          0      BK -73.95800  40.71867
# 445           17            8          0      BK -73.86704  40.66269
# 102           20            8          1      BK -74.01111  40.67389
# 660           33           61          0      BX -73.89362  40.85424
# 458           61          122          0      MN -73.96531  40.80677
# 97            31          157          1      BK -73.97712  40.66538
# 143           51           32          0      BX -73.91876  40.85393
# 232           26           12          0      BX -73.84392  40.81786
# 99            58           25          0      BX -73.91903  40.85364
# 124           57           26          0      BX -73.91911  40.85357
# 175           40           51          0      BK -73.95170  40.68477
# 527           25           61          0      MN -73.97211  40.79544
# 113           51           32          0      BX -73.91868  40.85401
# 379           52           69          1      BX -73.89513  40.83194
# 217           87           27          1      QN -73.92535  40.75194
# 177           16           10          0      BK -73.99775  40.67368
# 552          142           12          1      BK -73.97255  40.69840
# 676           67           61          0      BX -73.88953  40.83378
# 108           69           14          0      MN -73.93766  40.79884
# 378           19           16          1      QN -73.94495  40.75218
# 276           40           46          0      BK -73.96120  40.71431
# 168           54           27          0      MN -74.00331  40.73599
# 490           80          118          0      MN -73.96602  40.80581
# 409          129           12          1      MN -74.01023  40.72684
# 482           86           97          1      MN -73.95882  40.77955
# 111           71           28          0      BX -73.91884  40.85386
# 581           40           15          0      BK -73.95361  40.72654
# 325           25           61          1      BK -73.95289  40.65977
# 555           48           95          0      MN -73.96584  40.80812
# 480           59           44          1      BX -73.89658  40.85521
# 448           25           64          1      BX -73.89054  40.81822
# 719           71          117          0      MN -73.96401  40.80448
# 684            8           12          1      BX -73.84048  40.83903
# 76            23           70          0      BK -73.99561  40.69392
# 514           50          167          1      BX -73.90539  40.88926
# 18            29           71          1      BX -73.88793  40.81354
# 24            44           50          1      BX -73.89891  40.81539
# 678           35           11          0      BK -73.95080  40.71737
# 57            64           39          1      MN -73.99065  40.74065
# 525           43           77          0      BK -73.97545  40.67718
# 272           49           38          0      MN -73.99021  40.72434
# 544           21           57          1      BK -73.99617  40.69240
# 653          137          167          0      BX -73.90921  40.89512
# 56            28          152          0      BX -73.91392  40.89442
# 658           62           76          1      MN -73.97685  40.78650
# 164           47           27          0      BX -73.89573  40.82022
# 440           59           21          0      BX -73.91467  40.82391
# 608           77           31          1      MN -73.99438  40.74646
# 610           17            8          0      MN -73.97574  40.72715
# 726           23          151          1      BK -73.96297  40.66940
# 631           74          131          0      MN -73.95969  40.80815
# 478           60           20          0      BX -73.91460  40.82388
# 266          299           85          0      MN -73.96655  40.79472
# 353           16           21          0      MN -73.98329  40.72305
# 101           89           27          0      MN -73.99771  40.71966
# 45            41            6          0      BX -73.93150  40.82441
# 381          115          165          0      BX -73.90883  40.89635
#
#        area_type
# 261   commercial
# 256  residential
# 614   industrial
# 415   commercial
# 445   commercial
# 102   commercial
# 660  residential
# 458  residential
# 97    commercial
# 143   commercial
# 232   commercial
# 99   residential
# 124  residential
# 175   commercial
# 527   commercial
# 113  residential
# 379   industrial
# 217   industrial
# 177  residential
# 552   commercial
# 676   commercial
# 108  residential
# 378  residential
# 276   commercial
# 168   commercial
# 490  residential
# 409   industrial
# 482   industrial
# 111  residential
# 581   industrial
# 325   commercial
# 555   industrial
# 480   industrial
# 448  residential
# 719  residential
# 684  residential
# 76    commercial
# 514   commercial
# 18   residential
# 24   residential
# 678   commercial
# 57   residential
# 525  residential
# 272   commercial
# 544   commercial
# 653   commercial
# 56   residential
# 658   industrial
# 164  residential
# 440  residential
# 608  residential
# 610  residential
# 726  residential
# 631   industrial
# 478  residential
# 266  residential
# 353   commercial
# 101  residential
# 45    commercial
# 381   commercial

# %%
#CONCLUSION: one big outliers in row 261: Thus, the value of this outlier (12.56) probably don't make sense because the the area of the green roof
    # is way bigger than the building floor area

#DECISION: Drop the row!

df.drop(index = 261, inplace = True)

# %%
#roof_height

fig,ax = plt.subplots(figsize = (5,5))
sns.boxplot(data = df, y = 'roof_height')
plt.show()

# %%
Q1 = df['roof_height'].quantile(0.25)
Q3 = df['roof_height'].quantile(0.75)

IQR = Q3 - Q1

lower_wisker4 = Q1 - 1.5*IQR
upper_wisker4 = Q3 + 1.5*IQR

print(lower_wisker4) # this wisker don't have any meaning because we only have positive values
print(upper_wisker4)
# Out:
# -148.5
# 383.5

# %%
#checking the rows with ouliers

df[df['roof_height']>upper_wisker4].sort_values('roof_height', ascending= False )
# Out:
#      green_roof_area  building_area  ratio_green_area  construction_year  \
# 90               788          52632              0.01               1990
# 171             7992          85500              0.09               1930
# 467             5126          85062              0.06               1990
# 573            14475          98911              0.15               1930
# 582             3101          71264              0.04               1990
# 148             9737          69806              0.14               1990
# 115             4848         145737              0.03               1990
# 580             9836          56895              0.17               1930
# 206             8144          52983              0.15               1960
# 526             3321         155406              0.02               1960
# 430              554          20184              0.03               1990
# 532             2497          56374              0.04               1960
# 36              2634          47633              0.06               1990
# 244              699          22095              0.03               1990
# 399              606          31661              0.02               1900
# 504             1336          32520              0.04               1990
# 670             9757          43174              0.23               1990
# 11              2010          86153              0.02               1960
# 520             2569          29251              0.09               1960
# 722            15313          47429              0.32               1930
# 562              329          35291              0.01               1960
# 636             6039          54940              0.11               1930
# 355             4483          24645              0.18               1990
# 274             6688          20021              0.33               1960
# 541             1240          12952              0.10               1990
# 666            15112          90706              0.17               1960
# 465              788          60505              0.01               1930
# 511             4853          35647              0.14               1930
# 93              9109          48599              0.19               1990
# 195             1736          19852              0.09               1990
# 713             2939          53465              0.05               1990
# 671             4288          27431              0.16               1990
# 403             1286          28866              0.04               1960
# 127             5171          81471              0.06               1930
# 483             1930          13288              0.15               1930
# 451             1659          38129              0.04               1990
# 398             1426          14642              0.10               1960
# 14              1237          29374              0.04               1990
# 152             1496          23565              0.06               1990
# 309             1315          27154              0.05               1960
# 622             9907          27162              0.36               1990
# 382             6672          78619              0.08               1990
# 584              144          66989              0.00               1900
# 92              4321          23767              0.18               1990
#
#      roof_height  ground_elev  digitized borough    xcoord    ycoord  \
# 90          1408            5          0      MN -74.01280  40.71256
# 171         1238           50          1      MN -73.98571  40.74847
# 467          887           60          1      MN -73.98505  40.75573
# 573          834           64          1      MN -73.97996  40.75927
# 582          755           35          0      MN -73.98978  40.75595
# 148          740            9          1      MN -74.01452  40.71437
# 115          714           84          0      MN -73.98330  40.76811
# 580          708           61          1      MN -73.97635  40.75611
# 206          700           44          1      MN -73.98612  40.75782
# 526          646           12          0      MN -74.01587  40.71269
# 430          627            8          0      BK -73.98587  40.69161
# 532          626           60          1      MN -73.98516  40.75482
# 36           609           25          0      MN -73.99449  40.75899
# 244          605           40          1      MN -73.99030  40.74864
# 399          597           36          0      MN -73.98936  40.75634
# 504          595          103          0      BK -73.98506  40.69158
# 670          591           72          0      MN -73.98370  40.76496
# 11           568           65          0      MN -73.97867  40.76009
# 520          548           63          1      MN -73.98394  40.75607
# 722          544           18          1      MN -74.00232  40.71371
# 562          511           75          0      MN -73.97903  40.75083
# 636          511           71          0      MN -73.97733  40.75899
# 355          506           80          0      MN -73.98177  40.77015
# 274          491           64          0      MN -73.97882  40.76123
# 541          484           11          0      MN -74.00697  40.70742
# 666          483           66          0      MN -73.97989  40.76240
# 465          480           69          0      MN -73.97693  40.76028
# 511          476           71          0      MN -73.97917  40.75124
# 93           467            4          0      QN -73.94298  40.74852
# 195          450           33          0      MN -73.99239  40.74406
# 713          449           38          0      MN -73.99826  40.75691
# 671          446           10          1      MN -74.01769  40.70575
# 403          446           75          0      MN -73.98267  40.76588
# 127          442           36          0      MN -73.98658  40.74159
# 483          431           62          0      MN -73.97472  40.75965
# 451          425           23          0      MN -73.94763  40.78512
# 398          422           59          0      MN -73.96581  40.76221
# 14           410           40          0      MN -73.99113  40.74436
# 152          405           68          0      MN -73.98399  40.76431
# 309          403           33          0      MN -73.95236  40.76685
# 622          393           10          1      MN -74.01700  40.70692
# 382          393            6          0      QN -73.95598  40.74780
# 584          389           48          0      MN -73.97564  40.75268
# 92           384           24          0      MN -73.95931  40.75985
#
#        area_type
# 90    commercial
# 171   industrial
# 467   commercial
# 573  residential
# 582  residential
# 148  residential
# 115  residential
# 580  residential
# 206   commercial
# 526  residential
# 430   commercial
# 532   commercial
# 36    industrial
# 244   commercial
# 399  residential
# 504   commercial
# 670   commercial
# 11    commercial
# 520   commercial
# 722  residential
# 562   commercial
# 636  residential
# 355   commercial
# 274   industrial
# 541  residential
# 666   commercial
# 465  residential
# 511  residential
# 93    commercial
# 195  residential
# 713   commercial
# 671   commercial
# 403   commercial
# 127  residential
# 483   commercial
# 451   industrial
# 398  residential
# 14    commercial
# 152  residential
# 309       public
# 622  residential
# 382  residential
# 584  residential
# 92    commercial

# %%
#CONCLUSION: two big outliers in rows 90 and 71. Here we will not drop them, because we want that our models 
#can make predictions in buildings with bigger heights. We have to keep in mind that in NY there are a lot 
#of tall buildings that can have a great variety of heights.

#DECISION: keep all the rows!

# %%
#ground_elev

fig,ax = plt.subplots(figsize = (5,5))
sns.boxplot(data = df, y = 'ground_elev')
plt.show()

# %%
Q1 = df['ground_elev'].quantile(0.25)
Q3 = df['ground_elev'].quantile(0.75)

IQR = Q3 - Q1

lower_wisker5 = Q1 - 1.5*IQR
upper_wisker5 = Q3 + 1.5*IQR

df['ground_elev'].min() # -4

print(lower_wisker5) # this wisker don't have any meaning because we only have positive values
print(upper_wisker5)
# Out:
# -54.0
# 130.0

# %%
df[df['ground_elev']>upper_wisker5].sort_values('ground_elev', ascending= False )
# Out:
#      green_roof_area  building_area  ratio_green_area  construction_year  \
# 569             4774          11568              0.41               1930
# 653            22102          41835              0.53               1960
# 514             6402          11684              0.55               1930
# 381            16067          32603              0.49               1960
# 437              854          18755              0.05               1930
# 97               779           1031              0.76               1900
# 125              691          10520              0.07               1900
# 56              1794           3370              0.53               1960
# 726             8592          17045              0.50               1930
# 435              946          20292              0.05               1900
# 296              633           4251              0.15               1990
# 265             2642          71875              0.04               1960
# 432             2189          19801              0.11               1960
# 357              235           1370              0.17               1900
# 150             3137          48764              0.06               1900
# 393              249          11516              0.02               1900
# 402              261           1435              0.18               1900
# 376             2290          10512              0.22               1900
# 366              743           6622              0.11               1990
# 455              298           7962              0.04               1900
# 706              729           5876              0.12               1990
# 631             2834           5664              0.50               1900
#
#      roof_height  ground_elev  digitized borough    xcoord    ycoord  \
# 569           51          168          1      BX -73.88095  40.88708
# 653          137          167          0      BX -73.90921  40.89512
# 514           50          167          1      BX -73.90539  40.88926
# 381          115          165          0      BX -73.90883  40.89635
# 437           36          165          1      BK -74.00211  40.64692
# 97            31          157          1      BK -73.97712  40.66538
# 125           60          156          0      BX -73.89956  40.86924
# 56            28          152          0      BX -73.91392  40.89442
# 726           23          151          1      BK -73.96297  40.66940
# 435           48          147          0      BX -73.92539  40.84120
# 296           50          141          1      BK -73.98007  40.66510
# 265          179          141          0      MN -73.95991  40.80734
# 432          318          139          0      MN -73.94306  40.84478
# 357           55          139          0      BK -73.97240  40.67072
# 150          132          139          1      MN -73.96115  40.80916
# 393           98          137          0      MN -73.96146  40.80661
# 402           49          136          0      BK -73.97368  40.66961
# 376           17          134          0      MN -73.96298  40.80977
# 366           66          132          0      BX -73.92047  40.84742
# 455           60          132          0      BX -73.91987  40.84772
# 706           99          132          0      BX -73.89933  40.86012
# 631           74          131          0      MN -73.95969  40.80815
#
#        area_type
# 569       public
# 653   commercial
# 514   commercial
# 381   commercial
# 437  residential
# 97    commercial
# 125  residential
# 56   residential
# 726  residential
# 435   commercial
# 296   commercial
# 265   industrial
# 432   commercial
# 357  residential
# 150   industrial
# 393   industrial
# 402  residential
# 376  residential
# 366  residential
# 455   commercial
# 706  residential
# 631   industrial

# %%
#CONCLUSION: no big outliers seen. group of twenthy outliers but we'll not drop it since our dataset is not too big.

#DECISION: keep all the rows!

# %%
df.to_csv('../../Data/cleaned_data/green_roofs2.csv', index = False)
