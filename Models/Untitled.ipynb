# %%
import pandas as pd
import numpy as np

# %%
df_k4 = pd.read_csv('../Data/cleaned_data/clusters2_df.csv')
# Out:
#      building_area  roof_height borough  construction_year    area_type  \
# 0            14057           59      BK               1900       public
# 1             4463           13      MN               1900   commercial
# 2            13217           93      MN               1900   commercial
# 3             4311           99      MN               1900   commercial
# 4            35891          206      BX               1990   commercial
# ..             ...          ...     ...                ...          ...
# 725           6414          104      MN               1800  residential
# 726           2941          118      MN               1990       public
# 727           4350          175      MN               1990   industrial
# 728          20051           23      MN               1960   commercial
# 729           2164           84      MN               1900   industrial
#
#      green_roof_area  clusters_4
# 0                971           1
# 1                696           1
# ...

# %%
pd.read_csv('../Data/cleaned_data/clusters3_df.csv')
# Out:
#      building_area  roof_height borough  construction_year    area_type  \
# 0            14057           59      BK               1900       public
# 1             4463           13      MN               1900   commercial
# 2            13217           93      MN               1900   commercial
# 3             4311           99      MN               1900   commercial
# 4            35891          206      BX               1990   commercial
# ..             ...          ...     ...                ...          ...
# 705           6414          104      MN               1800  residential
# 706           2941          118      MN               1990       public
# 707           4350          175      MN               1990   industrial
# 708          20051           23      MN               1960   commercial
# 709           2164           84      MN               1900   industrial
#
#      green_roof_area  clusters_5
# 0                971           0
# 1                696           3
# ...
